# %%
def easy_tokenizer(text):
	ret = []
	for x in [',','.','--','!','?',';','(',')','/','"']:
		text = text.replace(x,' '+x+' ')
	for word in text.split(' '):
		if word == '': continue
		ret.append(word.lower())
	return ret

responses = []
fr = open('response.txt','rb')
for line in fr:
	text = line.strip('\r\n') # "Class is not valuable."
	words = easy_tokenizer(text) # ['class','is','not','valuable','.']
	responses.append(words)
fr.close()
# output
for words in responses: print words
# Out:
# ['the', 'content', 'is', 'sometimes', 'overwhelming']
# ['i', 'think', 'that', 'more', 'concrete', 'examples', 'could', 'be', 'useful', 'for', 'understanding', 'how', 'some', 'of', 'the', 'algorithms', 'work', '.']
# ['i', 'feel', 'like', 'i', 'am', 'teaching', 'myself', 'a', 'majority', 'of', 'the', 'material', 'outside', 'of', 'class', 'while', 'i', 'do', 'the', 'homework', '.', 'the', 'slides', 'can', 'sometimes', 'be', 'very', 'cluttered', '.', 'i', 'usually', 'look', 'up', 'explanations', 'for', 'a', 'lot', 'of', 'concepts', 'on', 'different', 'websites', '.']
# ['slides', 'are', 'unintuitive', 'and', 'cluttered', '.', 'i', 'find', 'myself', 'not', 'learning', 'in', 'class', '.', 'i', 'usually', 'have', 'to', 'teach', 'myself', 'the', 'material', '.', 'class', 'is', 'not', 'valuable', '.']
# ['comparative', 'grading', "doesn't", 'make', 'any', 'sense', 'for', 'this', 'class', '.', 'there', 'are', 'seniors', 'and', 'grad', 'students', 'in', 'this', 'class', 'where', 'priorities', 'are', 'vastly', 'different', ',', 'not', 'to', 'mention', 'the', 'different', 'coursework', 'loads', '.']
# ["it's", 'really', 'hard', 'to', 'do', 'the', 'homeworks', ',', 'because', 'there', "aren't", 'that', 'many', 'concrete', 'examples', 'with', 'the', 'math', 'done', 'in', 'class', 'and', 'in', 'the', 'book', '.']
# ['i', "don't", 'think', 'we', 'as', 'students', 'get', 'a', 'very', 'good', 'understanding', 'of', 'how', 'what', 'we', 'are', 'learning', 'is', 'used', 'in', 'the', 'real', 'world', '.', 'also', ',', 'i', 'would', 'love', 'to', 'do', 'more', 'example', 'questions', 'in', 'class', 'to', 'better', 'prepare', 'us', 'for', 'the', 'homework', 'assignments', ',', 'exams', ',', 'and', 'final', 'project', '.', 'a', 'lot', 'of', 'my', 'other', 'professors', 'have', 'started', 'using', 'handouts', 'to', 'increase', 'student', 'engagement', 'in', 'class', 'and', 'i', 'think', 'they', 'work', 'really', 'well', '.', 'the', 'handouts', 'would', 'have', '1-2', 'example', 'problems', 'that', 'we', 'work', 'through', 'together', 'as', 'a', 'class', '.', 'in', 'my', 'opinion', ',', 'this', 'is', 'the', 'best', 'change', 'prof', '.', 'jiang', 'could', 'make', 'to', 'improve', 'our', 'learning', 'in', 'this', 'course', '.']
# ['i', 'would', 'love', 'to', 'see', 'more', 'real-world', 'examples', 'of', 'the', 'techniques', 'being', 'taught', 'in', 'class', '.', 'i', 'think', 'we', 'get', 'really', 'simplified', 'examples', 'that', 'show', 'the', 'underlying', 'concept', ',', 'but', 'we', "don't", 'use', 'the', 'techniques', 'for', 'analysis', 'of', 'actual', 'datasets', ',', 'and', 'i', 'think', 'that', 'is', 'what', 'a', 'lot', 'of', 'people', 'are', 'taking', 'the', 'class', 'for', '.', 'i', 'would', 'also', 'love', 'to', 'see', 'some', 'more', 'programming', 'examples', 'so', 'we', 'know', 'how', 'to', 'actually', 'implement', 'these', 'techniques', ',', 'and', 'this', 'would', 'go', 'hand', 'in', 'hand', 'with', 'the', 'real-world', 'examples', '.']
# ['it', 'would', 'be', 'cool', 'if', 'you', 'could', 'prepare', 'some', 'in-class', 'exercises', 'that', 'we', 'could', 'do', 'on', 'our', 'own', '(', 'to', 'facilitate', 'learning', ',', 'not', 'for', 'a', 'grade', ')', 'and', 'then', 'discuss', 'with', 'you', 'as', 'a', 'class', 'to', 'make', 'sure', 'we', 'are', 'understanding', 'the', 'topics', 'you', 'are', 'talking', 'about', '.', 'keith', 'did', 'this', 'for', 'a', 'couple', 'of', 'the', 'classes', 'he', 'subbed', 'in', 'and', 'it', 'was', 'very', 'helpful', '.']
# ['i', 'do', 'not', 'like', 'how', 'long', 'homeworks', '1', 'and', '2', 'were', '(', 'homework', '3', 'is', 'a', 'vast', 'improvement', ')', '.', 'i', 'also', 'do', 'not', 'like', 'that', 'the', 'project', 'cannot', 'be', 'integrated', 'into', 'my', 'own', 'research', 'project', ',', 'yet', '(', 'as', 'a', 'grad', 'student', ')', 'i', 'am', 'supposed', 'to', 'invest', 'more', 'time', 'into', 'the', 'project', '?', 'it', 'seems', 'counterintuitive', '.', 'to', 'improve', 'the', 'class', ',', 'slowing', 'down', 'definitions', 'and', 'clarity', 'in', 'the', "examples'", 'solutions', 'on', 'the', 'slides', 'would', 'be', 'helpful', '.']
# ['did', 'not', 'like', 'how', 'long', 'the', 'first', 'homework', 'was', '--', 'thank', 'you', 'so', 'much', 'for', 'shortening', 'hw2', '!']
# ['professor', 'jiang', 'is', 'a', 'great', 'professor', ',', 'he', 'really', 'knows', 'his', 'stuff', '.', 'however', ',', 'when', 'he', 'is', 'explaining', 'things', ',', 'he', 'is', 'not', 'very', 'through', '-', 'probably', 'because', 'he', 'knows', 'it', 'very', 'well', '.', 'if', 'he', 'could', 'slow', 'down', 'a', 'little', 'and', 'provide', 'some', 'actual', 'programming', 'examples', 'then', 'it', 'would', 'significantly', 'help', 'us', 'understand', 'as', 'well', 'as', 'on', 'the', 'project', '.']
# ['much', 'of', 'the', 'large', 'amount', 'of', 'information', 'is', 'very', 'new', ',', 'especially', 'the', 'vocabulary', 'used', 'with', 'data', 'and', 'statistics', '.', 'i', 'understand', 'that', 'there', 'is', 'a', 'lot', 'of', 'cover', 'in', 'the', 'lecture', ',', 'but', 'it', 'is', 'hard', 'to', 'follow', 'with', 'the', 'speed', 'at', 'which', 'the', 'information', 'is', 'covered', '.', 'i', 'often', 'find', 'myself', 'confused', 'about', 'some', 'slides', 'and', 'the', 'in-class', 'explanation', '.']
# ['it', 'may', 'be', 'better', 'to', 'give', 'more', 'examples', 'and', 'more', 'details', 'in', 'the', 'slices', '.']
# ['1', '.', 'organization', 'of', 'the', 'slides', 'is', 'not', 'good', 'enough', '.', '2', '.', 'notes', 'on', 'board', 'is', 'hard', 'to', 'read', '.', 'maybe', 'you', 'can', 'use', 'slides', 'to', 'show', 'as', 'well', '.']
# ['prof', '.', 'jiang', 'is', 'a', 'very', 'good', 'interactive', 'teacher', '.', 'i', 'like', 'his', 'videos', '.', 'just', 'should', 'understand', 'that', 'this', 'is', 'our', 'first', 'data', 'science', 'class', '.', 'grad', 'students', 'may', 'have', 'had', 'an', 'undergraduate', 'class', '.', 'most', 'undergraduates', 'are', 'just', 'getting', 'exposed', 'to', 'this', 'subject', '.']
# ['glad', 'he', 'is', 'actually', 'in', 'the', 'classroom', 'now', ',', 'definitely', 'a', 'big', 'help', '.', 'candy', 'is', 'a', 'great', 'motivator', 'too', ':', ')']
# ['i', 'like', 'when', 'have', 'more', 'of', 'a', 'discussion', '/', 'questions', '.', 'i', 'think', 'the', 'lecture', 'is', 'sometimes', 'hard', 'to', 'follow', '.']
# ['more', 'clarity', 'on', 'what', 'exactly', 'we', 'need', 'to', 'know', 'for', 'tests', '/', 'class', 'in', 'general', '.', 'sections', 'in', 'book', ',', 'etc']
# ['sometimes', 'the', 'textbook', "isn't", 'the', 'most', 'straightforward', ',', 'so', 'other', 'resources', 'might', 'be', 'helpful', ',', 'and', 'sometimes', "it's", 'hard', 'to', 'make', 'sense', 'of', 'the', 'powerpoints', 'or', 'work', 'through', 'the', 'examples', 'after', 'class']
# ['because', 'the', 'first', 'three', 'weeks', 'were', 'taught', 'by', 'a', 'different', 'instructor', '(', 'i', 'understand', 'this', 'was', 'unpreventable', ')', 'i', 'feel', 'very', 'lost', 'about', 'the', 'direction', 'of', 'the', 'class', 'and', 'the', 'ultimate', 'goals', 'of', 'the', 'class']
# ['more', 'concrete', 'examples', ',', 'some', 'demos', 'on', 'how', 'to', 'start', 'the', 'project']
# ['showing', 'interactive', 'demos', 'using', 'say', 'jupyter', 'notebook', 'like', 'kieth', 'used', 'to', 'do', 'would', 'supplement', 'the', 'lectures', 'really', 'well', '.']
# ['the', 'project', 'could', 'be', 'groups', 'of', 'three']
# ['i', 'wish', 'there', 'was', 'more', 'room', 'for', 'creativity', 'on', 'the', 'project', '-', 'it', 'seems', 'like', 'we', 'are', 'all', 'doing', 'the', 'same', 'exact', 'thing']
# ['the', 'scope', 'of', 'the', 'project', 'still', 'seems', 'very', 'intimidating', '.']
# ['project', 'timeline', 'is', 'hazy', '.', 'seems', 'like', 'i', 'am', 'just', 'tossed', 'the', 'project', 'and', 'am', 'expected', 'to', 'finish', 'it', 'whenever', 'the', 'due', 'date', 'is', '.', 'seems', 'to', 'be', 'a', 'big', 'undertaking', 'without', 'much', 'guidance', '.']
# ['i', "don't", 'think', 'comparative', 'grading', 'is', 'the', 'right', 'choice']
# ["i'm", 'concerned', 'with', 'the', 'difficulty', 'of', 'it', '.', 'i', 'am', 'already', 'worried', 'that', 'i', "won't", 'be', 'able', 'to', 'finish', 'it', '.']
# ['i', 'still', 'have', 'some', 'concern', 'that', 'it', 'will', 'be', 'too', 'long', 'considering', 'we', "don't", 'do', 'much', 'of', 'the', 'actual', 'application', 'of', 'various', 'techniques', 'in', 'class', '.', "i'm", 'going', 'to', 'have', 'to', 'teach', 'myself', 'what', 'algorithms', '/', 'techniques', 'to', 'use', 'in', 'each', 'situation', ',', 'and', 'then', 'figure', 'out', 'how', 'to', 'apply', 'it', 'to', 'the', 'dataset', 'at', 'hand', 'without', 'having', 'seen', 'any', 'examples', 'of', 'either', '.']
# ['as', 'previously', 'stated', ',', 'the', 'vast', 'amount', 'of', 'work', '"', 'strongly', 'encouraged', '"', 'is', 'overwhelming', '.', 'it', "would've", 'been', 'great', 'if', 'it', 'were', 'more', 'open-ended', '.', 'for', 'example', ',', 'if', 'we', 'could', 'choose', 'to', 'do', 'handwritten', 'digit', 'recognition', ',', 'gesture', 'recognition', ',', 'what', 'have', 'you', ',', 'it', 'would', 'be', 'a', 'worthy', 'investment', 'for', 'the', 'amount', 'of', 'time', "we're", 'putting', 'in', '.', 'the', 'most', 'unclear', 'thing', 'about', 'the', 'project', 'is', 'the', 'following:', 'why', 'are', 'we', 'doing', 'this', 'specific', 'task', '?']
# ['i', 'wish', 'there', 'were', 'more', 'examples', 'of', 'previous', 'projects']
# ['just', 'started', ',', 'but', 'everything', 'is', 'good', '.']
# ['the', 'project', 'is', 'too', 'long', '-', 'it', 'has', 'too', 'many', 'parts', '.', 'comparative', 'grading', 'is', 'also', 'not', 'the', 'best', 'idea', '.', 'it', 'does', 'not', 'ensure', 'that', 'someone', 'will', 'get', 'a', '100%', ',', 'even', 'if', 'they', 'complete', 'the', '7', 'mandatory', 'tasks', '.', 'extra', 'credit', 'should', 'be', 'awarded', 'for', 'additional', 'tasks', 'but', '100%', 'should', 'be', 'given', 'if', 'the', '7', 'tasks', 'are', 'satisfactorily', 'completed', '.']
# ['is', 'it', 'necessary', 'to', 'work', 'in', 'a', 'team', 'of', '2', '?']
# ['except', 'for', 'the', 'basic', '7', 'tasks', ',', 'how', 'many', 'other', 'tasks', 'will', 'each', 'student', 'does', 'on', 'average', '(', 'according', 'to', 'your', 'past', 'experience', ')', '?', 'i', 'am', 'afraid', 'i', "don't", 'have', 'enough', 'time', 'to', 'complete', 'too', 'many', 'alternative', 'tasks', '.']
# ['i', 'wish', 'the', 'project', 'was', 'a', 'group', 'project', '.', 'i', 'also', 'do', 'not', 'like', 'competitive', 'grading', ',', 'especially', 'with', 'grad', 'students', '.', 'if', 'everyone', 'does', 'a', 'good', 'job', ',', 'everyone', 'should', 'get', 'an', 'a', '.', 'if', 'everyone', 'does', 'a', 'bad', 'job', ',', 'everyone', 'should', 'get', 'a', 'c', '.']
# ['having', 'a', 'partner', 'or', 'a', 'small', 'group', 'would', 'allow', 'us', 'to', 'not', 'only', 'develop', 'our', 'data', 'science', 'skills', ',', 'but', 'also', 'allow', 'us', 'the', 'opportunity', 'to', 'simulate', 'a', 'real-world', 'team', 'in', 'creating', 'a', 'project', '.']
# ['i', "don't", 'like', 'how', 'the', 'project', 'will', 'graded', 'comparatively', ',', 'i', 'think', 'if', 'someone', 'completes', 'all', 'of', 'the', 'tasks', 'correctly', ',', 'they', 'should', 'get', 'an', 'a', '.', 'also', ',', 'having', 'a', 'partner', 'or', 'small', 'group', 'would', 'help', 'immensely', 'because', 'we', 'started', 'the', 'project', 'later', 'in', 'the', 'semester', '.']
# ['can', 'we', 'do', 'teams', 'please', '!']
# ['not', 'yet', ',', 'havent', 'really', 'looked', 'at', 'it', 'yet']
# ['i', 'am', 'not', 'entirely', 'sure', 'about', 'the', 'whole', 'scope', 'of', 'the', 'project', 'and', 'i', 'am', 'confused', 'about', 'the', 'ultimate', 'goals', 'of', 'the', 'project']
# ['project', 'seems', 'way', 'too', 'big', 'for', 'an', 'undergraduate', 'course', ',', 'especially', 'since', 'it', 'is', 'an', 'individual', 'project', ';', 'combined', 'with', 'the', 'long', 'homework', 'assignments', ',', 'the', 'workload', 'for', 'the', 'course', 'is', 'just', 'too', 'high']
# ['i', 'have', 'just', 'started', 'the', 'project', ',', 'and', 'the', 'only', 'concern', 'i', 'have', 'is', 'that', 'it', 'seems', 'really', 'long', 'and', 'tedious', '.', 'it', 'would', 'have', 'been', 'easier', 'to', 'manage', 'if', 'we', 'could', 'work', 'in', 'teams', 'of', '2', 'or', '3', '.']
# ['i', 'have', 'no', 'idea', 'what', 'to', 'expect', 'for', 'this', 'test']
# ['main', 'thing', 'that', 'could', 'be', 'improved', 'i', 'think', 'is', 'the', 'slides', '.', 'they', 'could', 'be', 'simpler', 'with', 'more', 'concise', 'wording', '.', 'sometimes', "i'm", 'not', 'sure', 'how', 'certain', 'concepts', 'can', 'be', 'applied', 'to', 'real', 'data', 'set', '.', 'more', 'in', 'class', 'assignments', '.', 'in', 'class', 'work', 'i', 'find', 'is', 'always', 'extremely', 'useful', 'and', 'helps', 'me', 'understand', 'concepts', 'more', '.']
# ['are', 'the', 'exams', 'going', 'to', 'be', 'as', 'complex', '(', 'long', '/', 'tedious', ')', 'as', 'the', 'homework', 'assignments', '?']
# ['i', 'would', 'say', 'try', 'to', 'do', 'some', 'analysis', 'with', 'code', 'on', 'actual', 'datasets', 'for', 'the', 'algorithms', 'that', 'you', 'are', 'teaching', 'us']
# ['having', 'surveys', 'like', 'these', 'periodically', 'will', 'definitely', 'help', 'you', 'help', 'us', 'learn', '.', 'definitely', ',', 'keep', 'using', 'them', '.', 'welcome', 'to', 'notre', 'dame', '!']
# ['i', 'think', 'the', 'class', 'is', 'very', 'interesting', 'and', 'the', 'ta', 'is', 'also', 'very', 'nice', '.', 'however', ',', 'there', 'should', 'really', 'be', 'more', 'office', 'hours', '-', 'the', 'hours', 'picked', 'out', 'for', 'the', 'ta', 'and', 'prof', '.', 'jiang', 'is', 'not', 'sufficient', 'for', 'everyone', '.']
# ['in', 'general', ',', 'there', 'are', 'many', 'slides', 'with', 'very', 'large', 'amounts', 'of', 'information', '.', 'are', 'we', 'supposed', 'to', 'thoroughly', 'know', 'the', 'all', 'the', 'information', 'for', 'the', 'test', '?', 'is', 'this', 'course', '/', 'the', 'test', 'more', 'about', 'understanding', 'concepts', 'and', 'how', 'to', 'solve', 'the', 'problems', 'or', 'is', 'it', 'more', 'about', 'thorough', 'memorization', 'of', 'the', 'information', '?']
# ['none', 'yet', '.']
# ['sometimes', 'the', 'board', 'can', 'get', 'a', 'little', 'cluttered', 'and', 'hard', 'to', 'follow', '.', 'perhaps', 'just', 'organize', 'board', 'work', 'a', 'little', 'more', ',', 'that', 'would', 'definitely', 'help', '!']
# ['more', 'examples', 'might', 'be', 'helpful']
# ['in', 'general', 'i', 'feel', 'very', 'lost', 'in', 'the', 'structure', 'of', 'this', 'class', '.', 'i', 'think', 'that', 'is', 'because', 'of', 'the', 'changing', 'of', 'instructors', 'a', 'few', 'weeks', 'into', 'the', 'class', '.', 'the', 'original', 'instructor', "didn't", 'seem', 'to', 'know', 'what', 'was', 'necessary', 'to', 'cover', 'and', 'the', 'lectures', 'were', 'disjointed', 'and', 'hard', 'to', 'follow', '.', 'now', 'that', 'there', 'is', 'a', 'consistent', 'structure', ',', 'i', 'feel', 'like', 'i', 'am', 'very', 'much', 'behind', 'after', 'a', 'confusing', 'first', 'three', 'weeks']
# ['please', ',', 'scale', 'back', 'the', 'project', '-', 'most', 'students', "haven't", 'started', ',', 'because', "it's", 'just', 'too', 'daunting', 'in', 'its', 'current', 'form', ',', 'and', 'i', 'predict', 'the', 'final', 'grades', 'will', 'reflect', 'this']
# ['i', 'think', 'everybody', 'appreciates', 'the', 'effort', 'that', 'you', 'put', 'into', 'every', 'lecture', '.', 'i', 'personally', 'think', 'that', 'you', 'are', 'a', 'good', 'teacher', '.', 'also', ',', 'watching', 'alan', 'do', 'things', 'is', 'always', 'a', 'joy', '!']

# %%
stopwordset = set()
fr = open('stopwords.txt','rb')
for line in fr:
	word = line.strip('\r\n').lower()
	stopwordset.add(word)
fr.close()
stopwordset.add('class')

word2support = {}
for words in responses:
	for word in set(words):
		if word in stopwordset or len(word) == 1 or word.isdigit(): continue
		if not word in word2support:
			word2support[word] = 0
		word2support[word] += 1
# output
for [word,support] in sorted(word2support.items(),key=lambda x:-x[1]):
	if support == 1: break
	print word,support
# Out:
# project 16
# examples 10
# think 10
# work 8
# hard 7
# long 7
# slides 7
# homework 6
# good 6
# help 5
# started 5
# understand 5
# students 5
# know 4
# helpful 4
# assignments 4
# grad 4
# follow 4
# grading 4
# understanding 4
# actual 4
# first 4
# lot 4
# make 4
# data 4
# jiang 4
# course 3
# find 3
# group 3
# cluttered 3
# big 3
# wish 3
# lecture 3
# tasks 3
# prof 3
# great 3
# thing 3
# feel 3
# learning 3
# use 3
# concepts 3
# general 3
# comparative 3
# different 3
# used 3
# student 3
# concrete 3
# algorithms 3
# time 3
# in-class 2
# concern 2
# questions 2
# love 2
# going 2
# board 2
# weeks 2
# real 2
# material 2
# finish 2
# homeworks 2
# vast 2
# lost 2
# large 2
# small 2
# lectures 2
# idea 2
# taught 2
# teams 2
# techniques 2
# scope 2
# real-world 2
# team 2
# little 2
# teach 2
# teacher 2
# improve 2
# programming 2
# exams 2
# useful 2
# necessary 2
# clarity 2
# undergraduate 2
# prepare 2
# three 2
# final 2
# teaching 2
# instructor 2
# datasets 2
# demos 2
# science 2
# supposed 2
# example 2
# interactive 2
# confused 2
# analysis 2
# sense 2
# partner 2
# complete 2
# tedious 2
# information 2
# things 2
# book 2
# test 2
# problems 2
# hand 2
# cover 2
# ultimate 2
# goals 2

# %%
word2count = {}
for words in responses:
	for word in words:
		if word in stopwordset or len(word) == 1 or word.isdigit(): continue
		if not word in word2count:
			word2count[word] = 0
		word2count[word] += 1
bigram2score = {} # bigram's count, first word's count, second word's count, significance score
L = 0
for words in responses:
	n = len(words)
	L += n
	for i in range(0,n-1):
		if words[i] in word2count and words[i+1] in word2count:
			bigram = words[i]+'_'+words[i+1]
			if not bigram in bigram2score:
				bigram2score[bigram] = [0,word2count[words[i]],word2count[words[i+1]],0.0]
			bigram2score[bigram][0] += 1
for bigram in bigram2score:
	bigram2score[bigram][3] = (1.0*bigram2score[bigram][0] -  \
		1.0*bigram2score[bigram][1]*bigram2score[bigram][2]/L) / \
		( (1.0*bigram2score[bigram][0])**0.5 )
# output
print 'bigram','count-bigram','count-first-word','count-second-word','significance-score'
for [bigram,score] in sorted(bigram2score.items(),key=lambda x:-x[1][3]):
	print bigram,score[0],score[1],score[2],score[3]
# Out:
# bigram count-bigram count-first-word count-second-word significance-score
# comparative_grading 3 3 4 1.7284196738
# grad_students 3 4 5 1.72599891795
# homework_assignments 3 6 4 1.72478854003
# concrete_examples 3 3 13 1.72024962282
# ultimate_goals 2 2 2 1.41273115822
# small_group 2 2 3 1.41198995614
# three_weeks 2 2 3 1.41198995614
# actual_datasets 2 4 2 1.41124875407
# first_three 2 4 2 1.41124875407
# data_science 2 4 2 1.41124875407
# programming_examples 2 2 13 1.40457793538
# real-world_examples 2 3 13 1.39976012188
# concise_wording 1 1 1 0.999475890985
# satisfactorily_completed 1 1 1 0.999475890985
# watching_alan 1 1 1 0.999475890985
# coursework_loads 1 1 1 0.999475890985
# worthy_investment 1 1 1 0.999475890985
# getting_exposed 1 1 1 0.999475890985
# right_choice 1 1 1 0.999475890985
# shortening_hw2 1 1 1 0.999475890985
# specific_task 1 1 1 0.999475890985
# extra_credit 1 1 1 0.999475890985
# examples'_solutions 1 1 1 0.999475890985
# previous_projects 1 1 1 0.999475890985
# notre_dame 1 1 1 0.999475890985
# current_form 1 1 1 0.999475890985
# graded_comparatively 1 1 1 0.999475890985
# handwritten_digit 1 1 1 0.999475890985
# jupyter_notebook 1 1 1 0.999475890985
# underlying_concept 1 1 1 0.999475890985
# explaining_things 1 1 2 0.998951781971
# gesture_recognition 1 1 2 0.998951781971
# real_world 1 2 1 0.998951781971
# hours_picked 1 2 1 0.998951781971
# extremely_useful 1 1 2 0.998951781971
# showing_interactive 1 1 2 0.998951781971
# large_amounts 1 2 1 0.998951781971
# bad_job 1 1 2 0.998951781971
# consistent_structure 1 1 2 0.998951781971
# original_instructor 1 1 2 0.998951781971
# science_skills 1 2 1 0.998951781971
# in-class_explanation 1 2 1 0.998951781971
# office_hours 1 1 2 0.998951781971
# final_grades 1 2 1 0.998951781971
# digit_recognition 1 1 2 0.998951781971
# in-class_exercises 1 2 1 0.998951781971
# vast_improvement 1 2 1 0.998951781971
# change_prof 1 1 3 0.998427672956
# vocabulary_used 1 1 3 0.998427672956
# student_engagement 1 3 1 0.998427672956
# increase_student 1 1 3 0.998427672956
# great_motivator 1 3 1 0.998427672956
# 1-2_example 1 1 3 0.998427672956
# go_hand 1 1 3 0.998427672956
# exact_thing 1 1 3 0.998427672956
# big_undertaking 1 3 1 0.998427672956
# main_thing 1 1 3 0.998427672956
# organize_board 1 1 3 0.998427672956
# unclear_thing 1 1 3 0.998427672956
# kieth_used 1 1 3 0.998427672956
# interactive_teacher 1 2 2 0.997903563941
# facilitate_learning 1 1 4 0.997903563941
# different_coursework 1 4 1 0.997903563941
# exams_going 1 2 2 0.997903563941
# data_set 1 4 1 0.997903563941
# actual_application 1 4 1 0.997903563941
# vastly_different 1 1 4 0.997903563941
# different_websites 1 4 1 0.997903563941
# competitive_grading 1 1 4 0.997903563941
# interactive_demos 1 2 2 0.997903563941
# confusing_first 1 1 4 0.997903563941
# certain_concepts 1 1 4 0.997903563941
# various_techniques 1 1 5 0.997379454927
# example_problems 1 3 2 0.996855345912
# help_immensely 1 6 1 0.996855345912
# great_professor 1 3 2 0.996855345912
# example_questions 1 3 2 0.996855345912
# real-world_team 1 3 2 0.996855345912
# long_considering 1 7 1 0.996331236897
# tasks_correctly 1 7 1 0.996331236897
# additional_tasks 1 1 7 0.996331236897
# alternative_tasks 1 1 7 0.996331236897
# mandatory_tasks 1 1 7 0.996331236897
# professor_jiang 1 2 4 0.995807127883
# make_sense 1 4 2 0.995807127883
# different_instructor 1 4 2 0.995807127883
# actual_programming 1 4 2 0.995807127883
# undergraduate_course 1 2 4 0.995807127883
# real_data 1 2 4 0.995807127883
# little_cluttered 1 3 3 0.995283018868
# good_teacher 1 6 2 0.993710691824
# grad_student 1 4 3 0.993710691824
# good_job 1 6 2 0.993710691824
# good_interactive 1 6 2 0.993710691824
# simplified_examples 1 1 13 0.993186582809
# personally_think 1 1 13 0.993186582809
# long_homeworks 1 7 2 0.992662473795
# first_data 1 4 4 0.991614255765
# understanding_concepts 1 4 4 0.991614255765
# big_help 1 3 6 0.990566037736
# understand_concepts 1 5 4 0.989517819706
# project_timeline 1 23 1 0.987945492662
# research_project 1 1 23 0.987945492662
# individual_project 1 1 23 0.987945492662
# good_understanding 1 6 4 0.987421383648
# use_slides 1 3 8 0.987421383648
# first_homework 1 4 6 0.987421383648
# algorithms_work 1 3 9 0.985849056604
# board_work 1 3 9 0.985849056604
# think_comparative 1 13 3 0.979559748428
# long_homework 1 7 6 0.977987421384
# final_project 1 2 23 0.975890985325
# group_project 1 3 23 0.963836477987

# %%
bigramdict = {}
for bigram in bigram2score:
	if bigram2score[bigram][0] > 1:
		[firstword,secondword] = bigram.split('_')
		if not firstword in bigramdict:
			bigramdict[firstword] = set()
		bigramdict[firstword].add(secondword)

transactions = [] # response
for words in responses:
	transaction = set() # set of words/bigrams
	n = len(words)
	i = 0
	while i < n:
		if words[i] in bigramdict and i+1 < n and words[i+1] in bigramdict[words[i]]:
			transaction.add(words[i]+'_'+words[i+1])
			i += 2
			continue
		if words[i] in stopwordset or len(words[i]) == 1 or words[i].isdigit():
			i += 1
			continue
		transaction.add(words[i])
		i += 1
	transactions.append(list(transaction))
# output
for transaction in transactions:
	print transaction
# Out:
# ['concrete_examples', 'useful', 'work', 'understanding', 'algorithms', 'think']
# ['different', 'concepts', 'look', 'feel', 'material', 'websites', 'slides', 'majority', 'lot', 'cluttered', 'teaching', 'explanations', 'homework']
# ['material', 'valuable', 'slides', 'learning', 'cluttered', 'teach', 'find', 'unintuitive']
# ['seniors', 'different', 'make', 'priorities', 'mention', 'vastly', 'sense', 'comparative_grading', 'loads', 'coursework', 'grad_students']
# ['homeworks', 'concrete_examples', 'hard', 'book', 'math']
# ['handouts', 'love', 'learning', 'professors', 'course', 'used', 'questions', 'world', 'prepare', 'make', 'engagement', 'increase', 'started', 'lot', 'prof', 'final', 'real', 'good', 'students', '1-2', 'problems', 'understanding', 'student', 'homework_assignments', 'change', 'improve', 'jiang', 'work', 'think', 'project', 'exams', 'opinion', 'example']
# ['use', 'concept', 'love', 'know', 'people', 'taking', 'real-world_examples', 'actual_datasets', 'analysis', 'hand', 'underlying', 'see', 'taught', 'simplified', 'examples', 'lot', 'programming_examples', 'go', 'implement', 'think', 'techniques']
# ['couple', 'helpful', 'prepare', 'grade', 'keith', 'in-class', 'make', 'topics', 'understanding', 'talking', 'classes', 'learning', 'exercises', 'subbed', 'facilitate', 'discuss', 'cool']
# ['slowing', 'solutions', 'clarity', 'research', 'long', 'improvement', "examples'", 'integrated', 'homework', 'slides', 'student', 'homeworks', 'vast', 'improve', 'counterintuitive', 'helpful', 'invest', 'project', 'supposed', 'time', 'definitions', 'grad']
# ['shortening', 'hw2', 'homework', 'long', 'first']
# ['explaining', 'great', 'slow', 'jiang', 'knows', 'provide', 'things', 'professor', 'little', 'project', 'stuff', 'understand', 'programming_examples', 'actual', 'help']
# ['slides', 'information', 'used', 'explanation', 'covered', 'vocabulary', 'speed', 'in-class', 'hard', 'cover', 'confused', 'large', 'statistics', 'understand', 'follow', 'lot', 'lecture', 'new', 'data', 'find']
# ['details', 'slices', 'examples', 'give']
# ['use', 'good', 'read', 'notes', 'hard', 'slides', 'board', 'organization']
# ['good', 'jiang', 'videos', 'getting', 'exposed', 'subject', 'undergraduates', 'data_science', 'understand', 'prof', 'first', 'undergraduate', 'teacher', 'grad_students', 'interactive']
# ['classroom', 'motivator', 'great', 'help', 'big', 'candy', 'glad']
# ['discussion', 'hard', 'questions', 'follow', 'lecture', 'think']
# ['tests', 'general', 'book', 'know', 'clarity', 'sections']
# ['work', 'helpful', 'straightforward', 'make', 'hard', 'textbook', 'examples', 'sense', 'powerpoints', 'resources']
# ['unpreventable', 'different', 'ultimate_goals', 'lost', 'feel', 'direction', 'first_three', 'taught', 'understand', 'weeks', 'instructor']
# ['concrete_examples', 'demos', 'project', 'start']
# ['supplement', 'lectures', 'used', 'jupyter', 'showing', 'demos', 'notebook', 'kieth', 'interactive']
# ['room', 'wish', 'creativity', 'project', 'thing', 'exact']
# ['project', 'scope', 'intimidating']
# ['finish', 'tossed', 'undertaking', 'timeline', 'guidance', 'hazy', 'project', 'date', 'big', 'expected']
# ['comparative_grading', 'right', 'think', 'choice']
# ['difficulty', 'concerned', 'finish', 'worried']
# ['considering', 'use', 'actual', 'figure', 'long', 'dataset', 'application', 'going', 'various', 'examples', 'hand', 'situation', 'algorithms', 'teach', 'techniques', 'apply', 'concern']
# ['unclear', 'stated', 'investment', 'recognition', 'encouraged', 'specific', 'following:', 'choose', 'handwritten', 'digit', 'open-ended', 'putting', 'worthy', 'overwhelming', 'vast', 'great', 'task', 'work', 'project', 'thing', 'time', 'example', 'gesture']
# ['wish', 'examples', 'projects', 'previous']
# ['started', 'good']
# ['given', 'tasks', 'mandatory', 'complete', 'extra', '100%', 'idea', 'long', 'awarded', 'project', 'credit', 'parts', 'ensure', 'satisfactorily', 'comparative_grading', 'completed', 'additional']
# ['work', 'necessary', 'team']
# ['afraid', 'complete', 'average', 'time', 'experience', 'tasks', 'student', 'basic', 'alternative']
# ['good', 'group', 'grading', 'wish', 'bad', 'competitive', 'project', 'job', 'grad_students']
# ['small_group', 'develop', 'simulate', 'skills', 'real-world', 'project', 'data_science', 'allow', 'team', 'partner', 'opportunity', 'creating']
# ['small_group', 'tasks', 'graded', 'started', 'comparatively', 'think', 'project', 'semester', 'correctly', 'partner', 'immensely', 'completes', 'help']
# ['teams']
# ['looked', 'havent']
# ['project', 'scope', 'confused', 'ultimate_goals']
# ['high', 'workload', 'big', 'long', 'project', 'course', 'individual', 'combined', 'homework_assignments', 'undergraduate']
# ['tedious', 'work', 'started', 'manage', 'long', 'teams', 'project', 'easier', 'concern']
# ['test', 'idea', 'expect']
# ['applied', 'real', 'set', 'improved', 'concise', 'wording', 'certain', 'work', 'extremely', 'find', 'slides', 'thing', 'assignments', 'understand', 'helps', 'concepts', 'useful', 'main', 'data', 'think', 'simpler']
# ['tedious', 'going', 'long', 'complex', 'exams', 'homework_assignments']
# ['code', 'actual_datasets', 'analysis', 'try', 'algorithms', 'teaching']
# ['surveys', 'help', 'notre', 'welcome', 'keep', 'learn', 'periodically', 'dame']
# ['jiang', 'office', 'interesting', 'sufficient', 'hours', 'picked', 'prof', 'ta', 'think', 'nice']
# ['large', 'information', 'amounts', 'problems', 'general', 'slides', 'course', 'solve', 'supposed', 'concepts', 'test', 'understanding', 'memorization', 'know']
# []
# ['little', 'organize', 'help', 'hard', 'board', 'follow', 'cluttered', 'work']
# ['examples', 'helpful']
# ['lectures', 'instructor', 'necessary', 'lost', 'feel', 'hard', 'consistent', 'instructors', 'cover', 'general', 'first_three', 'disjointed', 'know', 'follow', 'changing', 'weeks', 'original', 'think', 'structure', 'confusing']
# ['current', 'predict', 'scale', 'daunting', 'form', 'students', 'project', 'started', 'grades', 'reflect', 'final']
# ['good', 'watching', 'things', 'appreciates', 'alan', 'teacher', 'personally', 'put', 'lecture', 'joy', 'effort', 'think']

# %%
# http://www.borgelt.net/pyfim.html	
from fim import apriori, fpgrowth
patterns = apriori(transactions,supp=-3) # +: percentage -: absolute number
# output
print '-------- Apriori --------'
for (pattern,support) in sorted(patterns,key=lambda x:-x[1]):
	print pattern,support
print 'Number of patterns:',len(patterns)
# Out:
# -------- Apriori --------
# ('project',) 16
# ('think',) 10
# ('work',) 8
# ('hard',) 7
# ('long',) 7
# ('slides',) 7
# ('examples',) 6
# ('good',) 6
# ('help',) 5
# ('started',) 5
# ('understand',) 5
# ('helpful',) 4
# ('follow', 'hard') 4
# ('follow',) 4
# ('know',) 4
# ('started', 'project') 4
# ('understanding',) 4
# ('make',) 4
# ('jiang',) 4
# ('long', 'project') 4
# ('lot',) 4
# ('concrete_examples',) 3
# ('wish',) 3
# ('big',) 3
# ('algorithms',) 3
# ('cluttered',) 3
# ('comparative_grading',) 3
# ('grad_students',) 3
# ('different',) 3
# ('lecture',) 3
# ('tasks',) 3
# ('general', 'know') 3
# ('general',) 3
# ('homework',) 3
# ('feel',) 3
# ('great',) 3
# ('use',) 3
# ('concepts', 'slides') 3
# ('concepts',) 3
# ('find', 'slides') 3
# ('find',) 3
# ('homework_assignments',) 3
# ('thing',) 3
# ('time',) 3
# ('course',) 3
# ('learning',) 3
# ('prof', 'jiang') 3
# ('prof',) 3
# ('used',) 3
# ('student',) 3
# ('work', 'think') 3
# ('work', 'project') 3
# Number of patterns: 52

# %%
patterns = fpgrowth(transactions,supp=-3)
# output
print '-------- FP-Growth --------'
for (pattern,support) in sorted(patterns,key=lambda x:-x[1]):
	print pattern,support
print 'Number of patterns:',len(patterns)
# Out:
# -------- FP-Growth --------
# ('project',) 16
# ('think',) 10
# ('work',) 8
# ('slides',) 7
# ('long',) 7
# ('hard',) 7
# ('good',) 6
# ('examples',) 6
# ('understand',) 5
# ('started',) 5
# ('help',) 5
# ('lot',) 4
# ('long', 'project') 4
# ('jiang',) 4
# ('make',) 4
# ('understanding',) 4
# ('started', 'project') 4
# ('know',) 4
# ('follow', 'hard') 4
# ('follow',) 4
# ('helpful',) 4
# ('work', 'project') 3
# ('work', 'think') 3
# ('student',) 3
# ('used',) 3
# ('prof', 'jiang') 3
# ('prof',) 3
# ('learning',) 3
# ('course',) 3
# ('time',) 3
# ('thing',) 3
# ('homework_assignments',) 3
# ('find', 'slides') 3
# ('find',) 3
# ('concepts', 'slides') 3
# ('concepts',) 3
# ('use',) 3
# ('great',) 3
# ('feel',) 3
# ('general', 'know') 3
# ('general',) 3
# ('homework',) 3
# ('tasks',) 3
# ('lecture',) 3
# ('different',) 3
# ('grad_students',) 3
# ('comparative_grading',) 3
# ('cluttered',) 3
# ('algorithms',) 3
# ('big',) 3
# ('wish',) 3
# ('concrete_examples',) 3
# Number of patterns: 52

# %%
patterns = fpgrowth(transactions,target='c',supp=-2,zmin=2)
# output
print '-------- Closed Non-single Itemsets --------'
for (pattern,support) in sorted(patterns,key=lambda x:-x[1]):
	print pattern,support
print 'Number of patterns:',len(patterns)
# Out:
# -------- Closed Non-single Itemsets --------
# ('follow', 'hard') 4
# ('started', 'project') 4
# ('long', 'project') 4
# ('general', 'know') 3
# ('concepts', 'slides') 3
# ('find', 'slides') 3
# ('prof', 'jiang') 3
# ('work', 'think') 3
# ('work', 'project') 3
# ('scope', 'project') 2
# ('tedious', 'long') 2
# ('board', 'hard') 2
# ('wish', 'project') 2
# ('sense', 'make') 2
# ('material', 'cluttered', 'slides') 2
# ('going', 'long') 2
# ('little', 'help') 2
# ('partner', 'small_group', 'project') 2
# ('concern', 'long') 2
# ('complete', 'tasks') 2
# ('useful', 'work', 'think') 2
# ('big', 'project') 2
# ('teacher', 'good') 2
# ('analysis', 'actual_datasets') 2
# ('instructor', 'feel', 'weeks', 'lost', 'first_three') 2
# ('large', 'information', 'slides') 2
# ('grad_students', 'good') 2
# ('different', 'feel') 2
# ('supposed', 'slides') 2
# ('techniques', 'examples', 'use', 'hand') 2
# ('lecture', 'follow', 'hard') 2
# ('lecture', 'think') 2
# ('tasks', 'project') 2
# ('exams', 'homework_assignments') 2
# ('questions', 'think') 2
# ('cover', 'follow', 'hard') 2
# ('homework', 'long') 2
# ('homework', 'slides') 2
# ('data', 'find', 'understand', 'slides') 2
# ('final', 'students', 'started', 'project') 2
# ('great', 'help') 2
# ('great', 'project') 2
# ('vast', 'time', 'project') 2
# ('problems', 'course', 'understanding') 2
# ('homework_assignments', 'course', 'project') 2
# ('homework_assignments', 'long') 2
# ('prepare', 'learning', 'understanding', 'make') 2
# ('thing', 'work') 2
# ('thing', 'project') 2
# ('help', 'project') 2
# ('helpful', 'examples') 2
# ('helpful', 'make') 2
# ('real', 'work', 'think') 2
# ('follow', 'think', 'hard') 2
# ('time', 'student') 2
# ('love', 'lot', 'think') 2
# ('improve', 'student', 'project') 2
# ('example', 'work', 'project') 2
# ('prof', 'good', 'jiang') 2
# ('prof', 'think', 'jiang') 2
# ('know', 'think') 2
# ('used', 'lot') 2
# ('started', 'good') 2
# ('started', 'work', 'project') 2
# ('started', 'think', 'project') 2
# ('understanding', 'work', 'think') 2
# ('make', 'work') 2
# ('jiang', 'understand') 2
# ('jiang', 'project') 2
# ('hard', 'slides') 2
# ('hard', 'work') 2
# ('good', 'think') 2
# ('good', 'project') 2
# ('lot', 'slides') 2
# Number of patterns: 74

# %%
rules = apriori(transactions,target='r',supp=-2,conf=70,report='sc')
# output
print '-------- One-to-Many Association Rules --------'
for (ruleleft,ruleright,support,confidence) in sorted(rules,key=lambda x:x[0]):
	print ruleleft,'-->',ruleright,support,confidence
print 'Number of rules:',len(rules)
# Out:
# -------- One-to-Many Association Rules --------
# actual_datasets --> ('analysis',) 0.0363636363636 1.0
# analysis --> ('actual_datasets',) 0.0363636363636 1.0
# cluttered --> ('material', 'slides') 0.0363636363636 1.0
# cluttered --> ('material',) 0.0363636363636 1.0
# course --> ('problems', 'understanding') 0.0363636363636 1.0
# course --> ('problems',) 0.0363636363636 1.0
# course --> ('homework_assignments', 'project') 0.0363636363636 1.0
# data --> ('find', 'understand', 'slides') 0.0363636363636 1.0
# data --> ('find', 'understand') 0.0363636363636 1.0
# data --> ('understand', 'slides') 0.0363636363636 1.0
# examples --> ('techniques', 'hand', 'use') 0.0363636363636 1.0
# examples --> ('techniques', 'hand') 0.0363636363636 1.0
# examples --> ('techniques', 'use') 0.0363636363636 1.0
# examples --> ('techniques',) 0.0363636363636 1.0
# examples --> ('hand', 'use') 0.0363636363636 1.0
# examples --> ('hand',) 0.0363636363636 1.0
# feel --> ('instructor', 'weeks', 'first_three', 'lost') 0.0363636363636 1.0
# feel --> ('instructor', 'weeks', 'first_three') 0.0363636363636 1.0
# feel --> ('instructor', 'weeks', 'lost') 0.0363636363636 1.0
# feel --> ('instructor', 'weeks') 0.0363636363636 1.0
# feel --> ('instructor', 'first_three', 'lost') 0.0363636363636 1.0
# feel --> ('instructor', 'first_three') 0.0363636363636 1.0
# feel --> ('instructor', 'lost') 0.0363636363636 1.0
# feel --> ('instructor',) 0.0363636363636 1.0
# feel --> ('weeks', 'first_three', 'lost') 0.0363636363636 1.0
# feel --> ('weeks', 'first_three') 0.0363636363636 1.0
# feel --> ('weeks', 'lost') 0.0363636363636 1.0
# feel --> ('weeks',) 0.0363636363636 1.0
# feel --> ('first_three', 'lost') 0.0363636363636 1.0
# feel --> ('first_three',) 0.0363636363636 1.0
# feel --> ('lost',) 0.0363636363636 1.0
# final --> ('students', 'started', 'project') 0.0363636363636 1.0
# final --> ('students', 'started') 0.0363636363636 1.0
# final --> ('students', 'project') 0.0363636363636 1.0
# final --> ('students',) 0.0363636363636 1.0
# find --> ('data', 'understand', 'slides') 0.0363636363636 1.0
# find --> ('data', 'understand') 0.0363636363636 1.0
# find --> ('data', 'slides') 0.0363636363636 1.0
# find --> ('data',) 0.0363636363636 1.0
# find --> ('understand', 'slides') 0.0363636363636 1.0
# first_three --> ('instructor', 'weeks', 'lost', 'feel') 0.0363636363636 1.0
# first_three --> ('instructor', 'weeks', 'lost') 0.0363636363636 1.0
# first_three --> ('instructor', 'weeks', 'feel') 0.0363636363636 1.0
# first_three --> ('instructor', 'weeks') 0.0363636363636 1.0
# first_three --> ('instructor', 'lost', 'feel') 0.0363636363636 1.0
# first_three --> ('instructor', 'lost') 0.0363636363636 1.0
# first_three --> ('instructor', 'feel') 0.0363636363636 1.0
# first_three --> ('instructor',) 0.0363636363636 1.0
# first_three --> ('weeks', 'lost', 'feel') 0.0363636363636 1.0
# first_three --> ('weeks', 'lost') 0.0363636363636 1.0
# first_three --> ('weeks', 'feel') 0.0363636363636 1.0
# first_three --> ('weeks',) 0.0363636363636 1.0
# first_three --> ('lost', 'feel') 0.0363636363636 1.0
# first_three --> ('lost',) 0.0363636363636 1.0
# follow --> ('lecture', 'hard') 0.0363636363636 1.0
# follow --> ('cover', 'hard') 0.0363636363636 1.0
# follow --> ('cover',) 0.0363636363636 1.0
# follow --> ('hard', 'think') 0.0363636363636 1.0
# general --> ('know',) 0.0545454545455 0.75
# good --> ('teacher',) 0.0363636363636 1.0
# hand --> ('techniques', 'use', 'examples') 0.0363636363636 1.0
# hand --> ('techniques', 'use') 0.0363636363636 1.0
# hand --> ('techniques', 'examples') 0.0363636363636 1.0
# hand --> ('techniques',) 0.0363636363636 1.0
# hand --> ('use', 'examples') 0.0363636363636 1.0
# hard --> ('board',) 0.0363636363636 1.0
# hard --> ('lecture', 'follow') 0.0363636363636 1.0
# hard --> ('cover', 'follow') 0.0363636363636 1.0
# hard --> ('cover',) 0.0363636363636 1.0
# hard --> ('follow', 'think') 0.0363636363636 1.0
# hard --> ('follow',) 0.0727272727273 1.0
# help --> ('little',) 0.0363636363636 1.0
# homework_assignments --> ('exams',) 0.0363636363636 1.0
# homework_assignments --> ('course', 'project') 0.0363636363636 1.0
# improve --> ('student', 'project') 0.0363636363636 1.0
# information --> ('large', 'slides') 0.0363636363636 1.0
# information --> ('large',) 0.0363636363636 1.0
# instructor --> ('weeks', 'first_three', 'lost', 'feel') 0.0363636363636 1.0
# instructor --> ('weeks', 'first_three', 'lost') 0.0363636363636 1.0
# instructor --> ('weeks', 'first_three', 'feel') 0.0363636363636 1.0
# instructor --> ('weeks', 'first_three') 0.0363636363636 1.0
# instructor --> ('weeks', 'lost', 'feel') 0.0363636363636 1.0
# instructor --> ('weeks', 'lost') 0.0363636363636 1.0
# instructor --> ('weeks', 'feel') 0.0363636363636 1.0
# instructor --> ('weeks',) 0.0363636363636 1.0
# instructor --> ('first_three', 'lost', 'feel') 0.0363636363636 1.0
# instructor --> ('first_three', 'lost') 0.0363636363636 1.0
# instructor --> ('first_three', 'feel') 0.0363636363636 1.0
# instructor --> ('first_three',) 0.0363636363636 1.0
# instructor --> ('lost', 'feel') 0.0363636363636 1.0
# instructor --> ('lost',) 0.0363636363636 1.0
# jiang --> ('prof', 'good') 0.0363636363636 1.0
# jiang --> ('prof', 'think') 0.0363636363636 1.0
# jiang --> ('prof',) 0.0545454545455 1.0
# know --> ('general',) 0.0545454545455 1.0
# large --> ('information', 'slides') 0.0363636363636 1.0
# large --> ('information',) 0.0363636363636 1.0
# learning --> ('prepare', 'understanding', 'make') 0.0363636363636 1.0
# learning --> ('prepare', 'understanding') 0.0363636363636 1.0
# learning --> ('prepare', 'make') 0.0363636363636 1.0
# learning --> ('prepare',) 0.0363636363636 1.0
# learning --> ('understanding', 'make') 0.0363636363636 1.0
# long --> ('tedious',) 0.0363636363636 1.0
# long --> ('going',) 0.0363636363636 1.0
# long --> ('concern',) 0.0363636363636 1.0
# lost --> ('instructor', 'weeks', 'first_three', 'feel') 0.0363636363636 1.0
# lost --> ('instructor', 'weeks', 'first_three') 0.0363636363636 1.0
# lost --> ('instructor', 'weeks', 'feel') 0.0363636363636 1.0
# lost --> ('instructor', 'weeks') 0.0363636363636 1.0
# lost --> ('instructor', 'first_three', 'feel') 0.0363636363636 1.0
# lost --> ('instructor', 'first_three') 0.0363636363636 1.0
# lost --> ('instructor', 'feel') 0.0363636363636 1.0
# lost --> ('instructor',) 0.0363636363636 1.0
# lost --> ('weeks', 'first_three', 'feel') 0.0363636363636 1.0
# lost --> ('weeks', 'first_three') 0.0363636363636 1.0
# lost --> ('weeks', 'feel') 0.0363636363636 1.0
# lost --> ('weeks',) 0.0363636363636 1.0
# lost --> ('first_three', 'feel') 0.0363636363636 1.0
# lost --> ('first_three',) 0.0363636363636 1.0
# lot --> ('love', 'think') 0.0363636363636 1.0
# lot --> ('love',) 0.0363636363636 1.0
# love --> ('lot', 'think') 0.0363636363636 1.0
# make --> ('sense',) 0.0363636363636 1.0
# make --> ('prepare', 'learning', 'understanding') 0.0363636363636 1.0
# make --> ('prepare', 'learning') 0.0363636363636 1.0
# make --> ('prepare', 'understanding') 0.0363636363636 1.0
# make --> ('prepare',) 0.0363636363636 1.0
# make --> ('learning', 'understanding') 0.0363636363636 1.0
# material --> ('cluttered', 'slides') 0.0363636363636 1.0
# partner --> ('small_group', 'project') 0.0363636363636 1.0
# partner --> ('small_group',) 0.0363636363636 1.0
# prepare --> ('learning', 'understanding', 'make') 0.0363636363636 1.0
# prepare --> ('learning', 'understanding') 0.0363636363636 1.0
# prepare --> ('learning', 'make') 0.0363636363636 1.0
# prepare --> ('understanding', 'make') 0.0363636363636 1.0
# problems --> ('course', 'understanding') 0.0363636363636 1.0
# prof --> ('jiang', 'good') 0.0363636363636 1.0
# prof --> ('jiang', 'think') 0.0363636363636 1.0
# prof --> ('jiang',) 0.0545454545455 0.75
# project --> ('scope',) 0.0363636363636 1.0
# project --> ('small_group', 'partner') 0.0363636363636 1.0
# project --> ('small_group',) 0.0363636363636 1.0
# project --> ('partner',) 0.0363636363636 1.0
# project --> ('final', 'students', 'started') 0.0363636363636 1.0
# project --> ('final', 'students') 0.0363636363636 1.0
# project --> ('final', 'started') 0.0363636363636 1.0
# project --> ('final',) 0.0363636363636 1.0
# project --> ('students', 'started') 0.0363636363636 1.0
# project --> ('students',) 0.0363636363636 1.0
# project --> ('vast', 'time') 0.0363636363636 1.0
# project --> ('vast',) 0.0363636363636 1.0
# project --> ('homework_assignments', 'course') 0.0363636363636 1.0
# project --> ('improve', 'student') 0.0363636363636 1.0
# project --> ('improve',) 0.0363636363636 1.0
# project --> ('example', 'work') 0.0363636363636 1.0
# project --> ('example',) 0.0363636363636 1.0
# project --> ('started', 'work') 0.0363636363636 1.0
# project --> ('started', 'think') 0.0363636363636 1.0
# project --> ('started',) 0.0727272727273 0.8
# slides --> ('material', 'cluttered') 0.0363636363636 1.0
# slides --> ('material',) 0.0363636363636 1.0
# slides --> ('large', 'information') 0.0363636363636 1.0
# slides --> ('large',) 0.0363636363636 1.0
# slides --> ('information',) 0.0363636363636 1.0
# slides --> ('supposed',) 0.0363636363636 1.0
# slides --> ('data', 'find', 'understand') 0.0363636363636 1.0
# slides --> ('data', 'find') 0.0363636363636 1.0
# slides --> ('data', 'understand') 0.0363636363636 1.0
# slides --> ('data',) 0.0363636363636 1.0
# slides --> ('concepts',) 0.0545454545455 1.0
# slides --> ('find', 'understand') 0.0363636363636 1.0
# slides --> ('find',) 0.0545454545455 1.0
# small_group --> ('partner', 'project') 0.0363636363636 1.0
# small_group --> ('partner',) 0.0363636363636 1.0
# started --> ('final', 'students', 'project') 0.0363636363636 1.0
# started --> ('final', 'students') 0.0363636363636 1.0
# started --> ('final', 'project') 0.0363636363636 1.0
# started --> ('final',) 0.0363636363636 1.0
# started --> ('students', 'project') 0.0363636363636 1.0
# started --> ('students',) 0.0363636363636 1.0
# started --> ('think', 'project') 0.0363636363636 1.0
# student --> ('improve', 'project') 0.0363636363636 1.0
# student --> ('improve',) 0.0363636363636 1.0
# students --> ('final', 'started', 'project') 0.0363636363636 1.0
# students --> ('final', 'started') 0.0363636363636 1.0
# students --> ('final', 'project') 0.0363636363636 1.0
# students --> ('final',) 0.0363636363636 1.0
# tasks --> ('complete',) 0.0363636363636 1.0
# techniques --> ('hand', 'use', 'examples') 0.0363636363636 1.0
# techniques --> ('hand', 'use') 0.0363636363636 1.0
# techniques --> ('hand', 'examples') 0.0363636363636 1.0
# techniques --> ('hand',) 0.0363636363636 1.0
# techniques --> ('use', 'examples') 0.0363636363636 1.0
# think --> ('useful', 'work') 0.0363636363636 1.0
# think --> ('useful',) 0.0363636363636 1.0
# think --> ('questions',) 0.0363636363636 1.0
# think --> ('love', 'lot') 0.0363636363636 1.0
# think --> ('love',) 0.0363636363636 1.0
# think --> ('real', 'work') 0.0363636363636 1.0
# think --> ('real',) 0.0363636363636 1.0
# think --> ('understanding', 'work') 0.0363636363636 1.0
# time --> ('vast', 'project') 0.0363636363636 1.0
# time --> ('vast',) 0.0363636363636 1.0
# understand --> ('data', 'find', 'slides') 0.0363636363636 1.0
# understand --> ('data', 'find') 0.0363636363636 1.0
# understand --> ('data', 'slides') 0.0363636363636 1.0
# understand --> ('data',) 0.0363636363636 1.0
# understanding --> ('problems', 'course') 0.0363636363636 1.0
# understanding --> ('problems',) 0.0363636363636 1.0
# understanding --> ('prepare', 'learning', 'make') 0.0363636363636 1.0
# understanding --> ('prepare', 'learning') 0.0363636363636 1.0
# understanding --> ('prepare', 'make') 0.0363636363636 1.0
# understanding --> ('prepare',) 0.0363636363636 1.0
# understanding --> ('learning', 'make') 0.0363636363636 1.0
# use --> ('techniques', 'hand', 'examples') 0.0363636363636 1.0
# use --> ('techniques', 'hand') 0.0363636363636 1.0
# use --> ('techniques', 'examples') 0.0363636363636 1.0
# use --> ('techniques',) 0.0363636363636 1.0
# use --> ('hand', 'examples') 0.0363636363636 1.0
# use --> ('hand',) 0.0363636363636 1.0
# vast --> ('time', 'project') 0.0363636363636 1.0
# weeks --> ('instructor', 'first_three', 'lost', 'feel') 0.0363636363636 1.0
# weeks --> ('instructor', 'first_three', 'lost') 0.0363636363636 1.0
# weeks --> ('instructor', 'first_three', 'feel') 0.0363636363636 1.0
# weeks --> ('instructor', 'first_three') 0.0363636363636 1.0
# weeks --> ('instructor', 'lost', 'feel') 0.0363636363636 1.0
# weeks --> ('instructor', 'lost') 0.0363636363636 1.0
# weeks --> ('instructor', 'feel') 0.0363636363636 1.0
# weeks --> ('instructor',) 0.0363636363636 1.0
# weeks --> ('first_three', 'lost', 'feel') 0.0363636363636 1.0
# weeks --> ('first_three', 'lost') 0.0363636363636 1.0
# weeks --> ('first_three', 'feel') 0.0363636363636 1.0
# weeks --> ('first_three',) 0.0363636363636 1.0
# weeks --> ('lost', 'feel') 0.0363636363636 1.0
# weeks --> ('lost',) 0.0363636363636 1.0
# work --> ('useful', 'think') 0.0363636363636 1.0
# work --> ('useful',) 0.0363636363636 1.0
# work --> ('real', 'think') 0.0363636363636 1.0
# work --> ('real',) 0.0363636363636 1.0
# work --> ('example', 'project') 0.0363636363636 1.0
# work --> ('example',) 0.0363636363636 1.0
# work --> ('understanding', 'think') 0.0363636363636 1.0
# Number of rules: 242
